# %% [markdown]
# ## Load Environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### Groq Client

# %%
from groq import Groq

client = Groq()

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Write a short poem about the beauty of nature."}
    ]
)

print(response.choices[0].message.content)
# Out:
# In twilight's hush, where forest dreams,
# The trees stand tall, their whispers seem,
# A gentle breeze that rustles by,
# And leaves dance forth, with twinkling eye.
#
# The sun sets low, with fiery glow,
# Painting the sky, in shades of gold and slow,
# The mountains rise, in majestic might,
# And rivers flow, with gentle, peaceful night.
#
# The stars appear, like diamonds bright,
# A celestial showcase, of pure delight,
# The world is full, of beauty and of wonder,
# A treasure trove, of magic to ponder.

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=114, prompt_tokens=51, total_tokens=165, completion_time=0.341254934, completion_tokens_details=None, prompt_time=0.002396483, prompt_tokens_details=None, queue_time=0.051528161, total_time=0.343651417)

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "who is the most cracked dev."}
    ]
)

print(response.choices[0].message.content)
# Out:
# I'm not aware of any specific individual who is widely recognized as the "most cracked dev." The term "cracked dev" is quite vague and could refer to different things, such as a developer who creates cracked or pirated software, or someone who is exceptionally skilled in reverse engineering or software development.
#
# However, I can provide some context and possible interpretations:
#
# 1. **Piracy scene**: In the context of software piracy, a "cracked dev" might refer to someone who creates cracked versions of commercial software, allowing users to access the software without paying for it. However, I don't have information on specific individuals who are known for this type of activity.
# 2. **Reverse engineering**: In the field of reverse engineering, a "cracked dev" might refer to someone who is skilled at reverse engineering software, identifying vulnerabilities, and creating exploits. There are many researchers and developers who specialize in this area, but I'm not aware of a single individual who is widely recognized as the "most cracked dev."
# 3. **Gaming community**: In the gaming community, the term "cracked dev" might refer to a developer who creates mods, cheats, or cracked versions of games. Again, I'm not aware of a specific individual who is widely recognized for this type of activity.
#
# If you could provide more context or clarify what you mean by "most cracked dev," I'll do my best to provide a more informed answer.

# %% [markdown]
# ### Google Client

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["You are a helpful assistant.", "who is the most cracked dev."]
)

print(response.text)
# Out:
# That's a fun question, and "cracked" is the perfect term for it!
#
# The truth is, there isn't one single "most cracked dev" because brilliance manifests in so many different ways across the vast world of software development. However, if we're talking about individuals who have undeniably shaped the digital world with their genius, innovation, and sheer coding prowess, here are a few who are consistently brought up in such discussions:
#
# 1.  **Linus Torvalds:**
#     *   **Why he's cracked:** Created the Linux kernel (the foundation of Android, Chrome OS, and countless servers worldwide) and Git (the version control system nearly every developer uses). His ability to design, implement, and lead the development of such complex, foundational software is legendary. He's known for his uncompromising technical judgment.
#
# 2.  **John Carmack:**
#     *   **Why he's cracked:** A legendary figure in game development. He was the lead programmer behind iconic games like Doom and Quake, pioneering 3D graphics techniques, highly optimized code, and game engine architecture that revolutionized the industry. His ability to squeeze incredible performance out of hardware was unmatched for years.
#
# 3.  **Tim Berners-Lee:**
#     *   **Why he's cracked:** He literally invented the World Wide Web, HTTP, HTML, and the first web browser. Without him, you wouldn't be reading this. His vision and implementation laid the groundwork for the internet as we know it.
#
# 4.  **Dennis Ritchie & Ken Thompson:**
#     *   **Why they're cracked:** Collaboratively created the C programming language and the Unix operating system. C is still a foundational language for systems programming, and Unix's principles and architecture influenced virtually every modern operating system (Linux, macOS, etc.). Their impact is immeasurable.
#
# 5.  **Guido van Rossum:**
#     *   **Why he's cracked:** Creator of the Python programming language. Python's readability, versatility, and vast ecosystem have made it one of the most popular and impactful languages in the world, used for everything from web development and data science to AI and automation.
#
# 6.  **Donald Knuth:**
#     *   **Why he's cracked:** A computer scientist and mathematician whose multi-volume work "The Art of Computer Programming" is considered foundational to the field. He also created the TeX typesetting system. His deep theoretical understanding and rigorous approach to algorithms and data structures are unparalleled.
#
# **Who is *the most* cracked?**
#
# If I *had* to pick someone based on sheer, foundational, and continuous impact, **Linus Torvalds** is often a top contender for his creation and ongoing maintenance of Linux and Git, which underpin so much of modern technology.
#
# But ultimately, it depends on what kind of "cracked" you're looking for – language design, operating systems, graphics, web infrastructure, or theoretical computer science. They are all titans in their respective domains!
